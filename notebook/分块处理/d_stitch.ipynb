# %%
# !pwd
# Out:
# /panda/eedy/jinsha/notebook

# %%
from mintpy.cli import image_stitch, mask, save_kmz, view

# %%
out_file = ' d_velocity_stitch.h5'
cmd = f'd106_velocity_stitch.h5  d033_velocity_stitch.h5 d135_velocity_stitch.h5 d062_velocity_stitch.h5 d164_velocity_stitch.h5' + f' -o {out_file}'
image_stitch.main(cmd.split())
# Out:
# files to be stitched: ['d106_velocity_stitch.h5', 'd033_velocity_stitch.h5', 'd135_velocity_stitch.h5', 'd062_velocity_stitch.h5', 'd164_velocity_stitch.h5']
# datasets to be stitched: ['velocity']
# ##################################################
# read velocity from file: d106_velocity_stitch.h5
# ------------------------------
# read data from file: d033_velocity_stitch.h5
# stitching ...
# grab corners of input matrices
# calculate corners of output matrix
# estimate difference in the overlapping area
# average offset between two matrices in the common area: 0.003155225583212985
# offset all pixel values in the 2nd matrix by 0.003155225583212985
# create output metadata and matrix in shape of (18362, 8753)
# update LENGTH/WIDTH: 18362/8753
# update Y/X_FIRST: 33.5/96.7
# update REF_Y/X: 847/1563
# plot stitching & shifting result ...
# figure size : [6.7, 11.2]
# save figure to file: d_velocity_stitch_01.png
# ------------------------------
# ...

# %%
cmd = f'd_velocity_stitch.h5 velocity '
cmd += '-v -4 4 --lalo-label --ylabel-rot 90 --scalebar 0.2 0.85 0.05 --cbar-nbins 4 '
cmd += f'--notitle --noverbose -o pic_d/d_velocity_stitch.png '
view.main(cmd.split())

# run save_kmz.py
cmd = f'd_velocity_stitch.h5 -u cm -v -4 4 -o pic_d/d_velocity_stitch.kmz'
save_kmz.main(cmd.split())
# Out:
# view.py d_velocity_stitch.h5 velocity -v -4 4 --lalo-label --ylabel-rot 90 --scalebar 0.2 0.85 0.05 --cbar-nbins 4 --notitle --noverbose -o pic_d/d_velocity_stitch.png
# data   coverage in y/x: (0, 0, 22276, 20801)
# subset coverage in y/x: (0, 0, 22276, 20801)
# update LENGTH, WIDTH, Y/XMAX
# update/add SUBSET_XMIN/YMIN/XMAX/YMAX: 0/0/22276/20801
# update Y/X_FIRST
# update REF_Y/X
# colormap: jet
# plotting data ...
# figure size : [12.9, 12.0]
# show reference point
# writing /panda/eedy/jinsha/notebook/pic_d/d_velocity_stitch_data.png with dpi=600
# writing /panda/eedy/jinsha/notebook/pic_d/d_velocity_stitch_cbar.png
# writing /panda/eedy/jinsha/notebook/pic_d/d_velocity_stitch.kml
# remove /panda/eedy/jinsha/notebook/pic_d/d_velocity_stitch.kml
# remove /panda/eedy/jinsha/notebook/pic_d/d_velocity_stitch_data.png
# remove /panda/eedy/jinsha/notebook/pic_d/d_velocity_stitch_cbar.png
# merged all files to /panda/eedy/jinsha/notebook/pic_d/d_velocity_stitch.kmz
