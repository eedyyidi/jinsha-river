# %%
# !pwd
# Out:
# /panda/eedy/jinsha/notebook

# %%
from mintpy.cli import image_stitch, mask, save_kmz, view

# %%
out_file = ' a_velocity_stitch.h5'
cmd = f'a172_velocity_stitch.h5  a099_velocity_stitch.h5 a026_velocity_stitch.h5 a128_velocity_stitch.h5' + f' -o {out_file}'
image_stitch.main(cmd.split())
# Out:
# files to be stitched: ['a172_velocity_stitch.h5', 'a099_velocity_stitch.h5', 'a026_velocity_stitch.h5', 'a128_velocity_stitch.h5']
# datasets to be stitched: ['velocity']
# ##################################################
# read velocity from file: a172_velocity_stitch.h5
# ------------------------------
# read data from file: a099_velocity_stitch.h5
# stitching ...
# grab corners of input matrices
# calculate corners of output matrix
# estimate difference in the overlapping area
# average offset between two matrices in the common area: 0.006953821366875176
# offset all pixel values in the 2nd matrix by 0.006953821366875176
# create output metadata and matrix in shape of (20253, 12422)
# update LENGTH/WIDTH: 20253/12422
# update Y/X_FIRST: 33.5/96.7
# update REF_Y/X: 372/1583
# plot stitching & shifting result ...
# figure size : [8.4, 11.0]
# save figure to file: a_velocity_stitch_01.png
# ------------------------------
# read data from file: a026_velocity_stitch.h5
# ...

# %%
cmd = f'a_velocity_stitch.h5 velocity '
cmd += '-v -4 4 --lalo-label --ylabel-rot 90 --scalebar 0.2 0.85 0.05 --cbar-nbins 4 '
cmd += f'--notitle --noverbose -o pic_a/a_velocity_stitch.png '
view.main(cmd.split())

# run save_kmz.py
cmd = f'a_velocity_stitch.h5 -u cm -v -4 4 -o pic_a/a_velocity_stitch.kmz'
save_kmz.main(cmd.split())
# Out:
# view.py a_velocity_stitch.h5 velocity -v -4 4 --lalo-label --ylabel-rot 90 --scalebar 0.2 0.85 0.05 --cbar-nbins 4 --notitle --noverbose -o pic_a/a_velocity_stitch.png
# data   coverage in y/x: (0, 0, 22279, 20796)
# subset coverage in y/x: (0, 0, 22279, 20796)
# update LENGTH, WIDTH, Y/XMAX
# update/add SUBSET_XMIN/YMIN/XMAX/YMAX: 0/0/22279/20796
# update Y/X_FIRST
# update REF_Y/X
# colormap: jet
# plotting data ...
# figure size : [12.9, 12.0]
# show reference point
# writing /panda/eedy/jinsha/notebook/pic_a/a_velocity_stitch_data.png with dpi=600
# writing /panda/eedy/jinsha/notebook/pic_a/a_velocity_stitch_cbar.png
# writing /panda/eedy/jinsha/notebook/pic_a/a_velocity_stitch.kml
# remove /panda/eedy/jinsha/notebook/pic_a/a_velocity_stitch.kml
# remove /panda/eedy/jinsha/notebook/pic_a/a_velocity_stitch_data.png
# remove /panda/eedy/jinsha/notebook/pic_a/a_velocity_stitch_cbar.png
# merged all files to /panda/eedy/jinsha/notebook/pic_a/a_velocity_stitch.kmz
